# %%
from itertools import permutations
import enchant

d = enchant.Dict("en_US")

print("Enter given letters separated by commas:")
print("Examples: [A,b,C,e] or [Z,y,G,o,G]")
l = input()
letters = [l.lower() for l in l.split(",")]
print()

print("Enter possible sizes separeted by commas:")
print("Examples: [3,4,5] or [8,4,5,2]")
nums = input()
numbers = [int(n) for n in nums.split(",")]
numbers.sort(reverse=True)
print()

for n in list(numbers):
    
    print()
    print("Words with " , n , "letters:")
    
    perm = permutations(letters, n)
    perm = set(["".join(p) for p in perm if (d.check("".join(p)))])
    perm = list(perm)
    perm.sort()
    for p in perm:
        
        print(p)
# Out:
# Enter given letters separated by commas:
# Examples: [A,b,C,e] or [Z,y,G,o,G]
# n,a,a,d,v,l
# ['n', 'a', 'a', 'd', 'v', 'l']
# Enter possible sizes separeted by commas:
# Examples: [3,4,5] or [8,4,5,2]
# 6,5,3,4
# [6, 5, 4, 3]
#
# Words with  6 letters:
# vandal
#
# Words with  5 letters:
# naval
# vanda
#
# Words with  4 letters:
# anal
# land
# lava
#
# Words with  3 letters:
# adv
# ala
# ana
# and
# avn
# lad
# lav
# nav
# val
# van

# %%
from itertools import permutations
import Dictionary as d

print("Enter given letters separated by commas:")
print("Examples: [A,b,C,e] or [Z,y,G,o,G]")
l = input()
letters = [l.lower() for l in l.split(",")]
print()

print("Enter possible sizes separeted by commas:")
print("Examples: [3,4,5] or [8,4,5,2]")
nums = input()
numbers = [int(n) for n in nums.split(",")]
numbers.sort(reverse=True)
print()

for n in list(numbers):
    
    print()
    print("Words with " , n , "letters:")
    
    perm = permutations(letters, n)
    perm = set(["".join(p) for p in perm if (d.check("".join(p)))])
    perm = list(perm)
    perm.sort()
    for p in perm:
        
        print(p)
# Out:
# Enter given letters separated by commas:
# Examples: [A,b,C,e] or [Z,y,G,o,G]
# n,a,a,d,v,l
#
# Enter possible sizes separeted by commas:
# Examples: [3,4,5] or [8,4,5,2]
# 6,5,3,4
#
#
# Words with  6 letters:
# vandal
#
# Words with  5 letters:
# aland
# naval
# vanda
#
# Words with  4 letters:
# alan
# anal
# land
# lava
# nada
# nala
#
# Words with  3 letters:
# aal
# ala
# ana
# and
# ava
# dal
# dan
# lad
# lav
# van
